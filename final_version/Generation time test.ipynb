# %%
CONFIG = {
        "background_path": "./backgrounds/b1_gen.png",
        "output_path": None,
        "overlays_path": "./insects/",
        "merge_path": "./backgrounds/b1_gen_rest.png",
        "n_samples": 300,
        "overlay_n":None,
        "n_clusters": 1,
        "ellipse_ranges": None,
        "ellipse_ratios": None,
        "wse_background": None,
        "ellipses_wse": None,
        "plot": False,
        "verbose": False
    }

# %%
from img_gen import generate_img
import time
file = open('/Users/jdv/Desktop/img_gen_times.csv', 'a')
for i in range(25,5000,50):
    CONFIG["n_samples"] = i
    start = time.time()
    generate_img(CONFIG)
    elapsed = time.time() - start
    s = "{},{}\n".format(i, elapsed)
    print(s, end="")
    file.write(s)
# Out:
# 25,0.9708447456359863
# 75,0.988461971282959
# 125,0.9363551139831543
# 175,1.0154781341552734
# 225,0.9856691360473633
# 275,1.1121840476989746
# 325,1.041883945465088
# 375,1.0674550533294678
# 425,1.1220011711120605
# 475,1.1604769229888916
# 525,1.1840641498565674
# 575,1.2239019870758057
# 625,1.297682285308838
# 675,1.2499849796295166
# 725,1.356247901916504
# 775,1.3266737461090088
# 825,1.404825210571289
# 875,1.4128739833831787
# 925,1.446432113647461
# 975,1.443925142288208
# 1025,1.5571000576019287
# 1075,1.509690284729004
# 1125,1.5565009117126465
# 1175,1.493523120880127
# 1225,1.6204159259796143
# 1275,1.7869832515716553
# 1325,1.6974778175354004
# 1375,1.8596198558807373
# 1425,1.9074170589447021
# 1475,1.7389271259307861
# 1525,1.7946670055389404
# 1575,2.010815143585205
# 1625,2.010305166244507
# 1675,2.023599147796631
# 1725,1.9109270572662354
# 1775,2.063110113143921
# 1825,2.089735984802246
# 1875,2.236176013946533
# 1925,2.2702391147613525
# 1975,2.217985153198242
# 2025,2.172307014465332
# 2075,2.293175220489502
# 2125,2.3483729362487793
# 2175,2.334476947784424
# 2225,2.427657127380371
# 2275,2.307864189147949
# 2325,2.3352770805358887
# 2375,2.376230001449585
# 2425,2.5506720542907715
# 2475,2.4460761547088623
# 2525,2.707577705383301
# 2575,2.671349048614502
# 2625,2.858774185180664
# 2675,2.7706010341644287
# 2725,2.7665462493896484
# 2775,2.845669984817505
# 2825,2.8231990337371826
# 2875,2.84926176071167
# 2925,2.8692851066589355
# 2975,3.080476999282837
# 3025,3.040290117263794
# 3075,3.279294967651367
# 3125,3.1147308349609375
# 3175,3.217135190963745
# 3225,3.1263182163238525
# 3275,3.5007688999176025
# 3325,3.312736988067627
# 3375,3.6101348400115967
# 3425,3.433867931365967
# 3475,3.633403778076172
# 3525,3.4118828773498535
# 3575,3.560344696044922
# 3625,3.4730758666992188
# 3675,3.734035015106201
# 3725,3.5568530559539795
# 3775,3.6886329650878906
# 3825,3.8363146781921387
# 3875,3.6398391723632812
# 3925,4.059960126876831
# 3975,4.232246160507202
# 4025,3.9452290534973145
# 4075,3.947521924972534
# 4125,3.9958860874176025
# 4175,4.171859979629517
# 4225,4.130905866622925
# 4275,4.27344012260437
# 4325,4.634655952453613
# 4375,4.270343065261841
# 4425,4.5809197425842285
# 4475,4.447119951248169
# 4525,4.7117931842803955
# 4575,4.600773096084595
# 4625,4.5535759925842285
# 4675,4.9749860763549805
# 4725,4.89483118057251
# 4775,4.695933818817139
# 4825,4.925727844238281
# 4875,4.872468948364258
# 4925,4.8704400062561035
# 4975,4.975544214248657
