# %%
import numpy as np
import pandas as pd

file = pd.read_csv("/Users/jdv/Desktop/ui_test_1E_wseSTRICT.csv")
file2 = pd.read_csv("/Users/jdv/Desktop/ui_test_1E_wseFREE.csv")
# file2_old = pd.read_csv("/Users/jdv/Desktop/ui_test_1E_wseFREE_OLD.csv")
# file2 = pd.read_csv("/Users/jdv/Desktop/ui_test_1E_wseFREE_OLD.csv")
y1 = np.array(file["ok"].values)
y2 = np.array(file2["ok"].values)


X1 = [file["n_samples"].values, file["ellipse_wse"].values, file["wse_background"].values]
X2 = [file2["n_samples"].values, file2["ellipse_wse"].values, file2["wse_background"].values]

X = []
for i in range(len(X1)):
    X.append(np.append(X1[i], X2[i]))
X[0] = X[0]/1000

X = np.rot90(X)
y = np.append(y1,y2)

X_orig = np.copy(X)
y_orig = np.copy(y)

# %%
from sklearn.svm import SVC
from sklearn import svm, datasets

model = svm.SVC(kernel="linear", C=0.30) #0.25
clf = model.fit(np.copy(X),np.copy(y))

# %%
x_t_0 = X[y==True, 0]
x_t_1 = X[y==True, 1]
x_t_2 = X[y==True, 2]

x_f_0 = X[y==False, 0]
x_f_1 = X[y==False, 1]
x_f_2 = X[y==False, 2]

xm, xM = X[:,0].min(), X[:, 0].max()
ym, yM = X[:,1].min(), X[:, 1].max()

# %%
# %matplotlib notebook
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt

z = lambda x,y: (-clf.intercept_[0]-clf.coef_[0][0]*x -clf.coef_[0][1]*y) / clf.coef_[0][2]

tmp = np.linspace(0,1,51)
x,y = np.meshgrid(tmp,tmp)
T = z(x,y)
T = T/np.max(T)
print(T.shape)
T = T - 1
T = T*2000



fig = plt.figure()
ax  = fig.add_subplot(111, projection='3d')
# ax.plot3D(x_t_0, x_t_1, x_t_2, 'ob')
# ax.plot3D(x_f_0, x_f_1, x_f_2, 'sr')
ax.plot_surface(x, y, T, alpha=1)
ax.view_init(30, 60)

ax.set_xlabel('n samples ($\cdot$ 1000)', fontsize=10)
ax.set_ylabel('ellipse area ($\cdot$ 12000)', fontsize=10)
ax.set_zlabel('ellipse $X_{wse}$', fontsize=10)
fig.savefig('./classifier_plots/3dplane_eWse_eArea_nSamples.pdf', dpi=120)
plt.show()
# Out:
# (51, 51)
# <img src="data:image/png;base64,..." width="640">

# %%
import matplotlib.pyplot as plt
from sklearn.inspection import DecisionBoundaryDisplay

X = np.copy(X_orig)

pair = [1,2]
# print(X[:, pair])
# print(X)
x_min, x_max = X[:, pair[0]].min() - 0.5, X[:, pair[0]].max() + 0.5
y_min, y_max = X[:, pair[1]].min() - 0.5, X[:, pair[1]].max() + 0.5


cm = plt.cm.RdBu

model = svm.SVC(kernel="rbf")
model.fit(X, y_orig)
DecisionBoundaryDisplay.from_estimator(model, X[:, pair], cmap=cm, ax=ax, eps=0.5)
plt.scatter(X[:, pair[0]], X[:, pair[1]], c=y, cmap=cm_bright, edgecolors="k")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [23], in <cell line: 17>()
#      15 model = svm.SVC(kernel="rbf")
#      16 model.fit(X, y_orig)
# ---> 17 DecisionBoundaryDisplay.from_estimator(model, X[:, pair], cmap=cm, ax=ax, eps=0.5)
#      18 plt.scatter(X[:, pair[0]], X[:, pair[1]], c=y, cmap=cm_bright, edgecolors="k")
#      19 plt.show()
#
# File ~/opt/miniconda3/envs/bp_testing/lib/python3.9/site-packages/sklearn/inspection/_plot/decision_boundary.py:306, in DecisionBoundaryDisplay.from_estimator(cls, estimator, X, grid_resolution, eps, plot_method, response_method, xlabel, ylabel, ax, **kwargs)
#     303     X_grid = np.c_[xx0.ravel(), xx1.ravel()]
#     305 pred_func = _check_boundary_response_method(estimator, response_method)
# --> 306 response = pred_func(X_grid)
#     308 # convert classes predictions into integers
#     309 if pred_func.__name__ == "predict" and hasattr(estimator, "classes_"):
#
# File ~/opt/miniconda3/envs/bp_testing/lib/python3.9/site-packages/sklearn/svm/_base.py:775, in BaseSVC.decision_function(self, X)
#     748 def decision_function(self, X):
#     749     """Evaluate the decision function for the samples in X.
#     750
#     751     Parameters
#    (...)
#     773     transformation of ovo decision function.
#     774     """
# --> 775     dec = self._decision_function(X)
#     776     if self.decision_function_shape == "ovr" and len(self.classes_) > 2:
#     777         return _ovr_decision_function(dec < 0, -dec, len(self.classes_))
#
# File ~/opt/miniconda3/envs/bp_testing/lib/python3.9/site-packages/sklearn/svm/_base.py:533, in BaseLibSVM._decision_function(self, X)
#     519 """Evaluates the decision function for the samples in X.
#     520
#     521 Parameters
#    (...)
#     529     in the model.
#     530 """
#     531 # NOTE: _validate_for_predict contains check for is_fitted
#     532 # hence must be placed before any other attributes are used.
# --> 533 X = self._validate_for_predict(X)
#     534 X = self._compute_kernel(X)
#     536 if self._sparse:
#
# File ~/opt/miniconda3/envs/bp_testing/lib/python3.9/site-packages/sklearn/svm/_base.py:611, in BaseLibSVM._validate_for_predict(self, X)
#     608 check_is_fitted(self)
#     610 if not callable(self.kernel):
# --> 611     X = self._validate_data(
#     612         X,
#     613         accept_sparse="csr",
#     614         dtype=np.float64,
#     615         order="C",
#     616         accept_large_sparse=False,
#     617         reset=False,
#     618     )
#     620 if self._sparse and not sp.isspmatrix(X):
#     621     X = sp.csr_matrix(X)
#
# File ~/opt/miniconda3/envs/bp_testing/lib/python3.9/site-packages/sklearn/base.py:600, in BaseEstimator._validate_data(self, X, y, reset, validate_separately, **check_params)
#     597     out = X, y
#     599 if not no_val_X and check_params.get("ensure_2d", True):
# --> 600     self._check_n_features(X, reset=reset)
#     602 return out
#
# File ~/opt/miniconda3/envs/bp_testing/lib/python3.9/site-packages/sklearn/base.py:400, in BaseEstimator._check_n_features(self, X, reset)
#     397     return
#     399 if n_features != self.n_features_in_:
# --> 400     raise ValueError(
#     401         f"X has {n_features} features, but {self.__class__.__name__} "
#     402         f"is expecting {self.n_features_in_} features as input."
#     403     )
#
# ValueError: X has 2 features, but SVC is expecting 3 features as input.
